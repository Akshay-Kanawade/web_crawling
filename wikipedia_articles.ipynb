# %% [markdown]
# import request                   -to get the http request.
# from bs4 import BeautifulSoup    -

# %%
import requests
from bs4 import BeautifulSoup
import random

# %%
req=requests.get("https://en.wikipedia.org/wiki/Main_Page")
req
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(req.text,"html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
a=soup.find_all("div",{"id":"mp-tfa"})
a
# Out:
# [<div id="mp-tfa"><div id="mp-tfa-img" style="float: left; margin: 0.5em 0.9em 0.4em 0em;">
#  <div class="thumbinner mp-thumb" style="background: transparent; border: none; padding: 0; max-width: 182px;">
# ...

# %%
for i in a:
    for s in i.find_all("a"):
        print(s.text)
# Out:
# Treaty of Lutatius
# Carthage
# Rome
# First Punic War
# had defeated a Carthaginian fleet
# blockade
# Sicily
# Senate
# peace treaty
# ratification
# reparations
# Sardinia
# Corsica
# Full article...
# Scorpion
# MAUD Committee
# Mysteries of Isis
# Archive
# By email
# More featured articles

# %%
req=requests.get("https://www.wikipedia.org")
req
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(req.text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia</title>
# <meta content="Wikipedia is a free online encyclopedia, created and edited by volunteers around the world and hosted by the Wikimedia Foundation." name="description"/>
# <script>
# document.documentElement.className = document.documentElement.className.replace( /(^|\s)no-js(\s|$)/, "$1js-enabled$2" );
# </script>
# <meta content="initial-scale=1,user-scalable=yes" name="viewport"/>
# <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
# <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>
# <link href="//creativecommons.org/licenses/by-sa/3.0/" rel="license"/>
# <style>
# ...

# %%
print(soup.find("a",{"class":"link-box"}).text,end="\n")
# Out:
# English
# 6 299 000+ articles

# %%
category=soup.find_all("a",{"class":"link-box"})
category
# Out:
# [<a class="link-box" data-slogan="The Free Encyclopedia" href="//en.wikipedia.org/" id="js-link-box-en" title="English â Wikipedia â The Free Encyclopedia">
#  <strong>English</strong>
#  <small><bdi dir="ltr">6 299 000+</bdi> <span>articles</span></small>
#  </a>,
#  <a class="link-box" data-slogan="ããªã¼ç¾ç§äºå
#  ¸" href="//ja.wikipedia.org/" id="js-link-box-ja" title="Nihongo â ã¦ã£ã­ããã£ã¢ â ããªã¼ç¾ç§äºå
#  ¸">
#  <strong>æ¥æ¬èª</strong>
#  <small><bdi dir="ltr">1 268 000+</bdi> <span>è¨äº</span></small>
#  </a>,
#  <a class="link-box" data-slogan="La enciclopedia libre" href="//es.wikipedia.org/" id="js-link-box-es" title="EspaÃ±ol â Wikipedia â La enciclopedia libre">
#  <strong>EspaÃ±ol</strong>
#  <small><bdi dir="ltr">1 684 000+</bdi> <span>artÃ­culos</span></small>
#  </a>,
# ...

# %%
for res in category:
    print (res.find('strong').text)
    print(res.find('small').text)
    print()
# Out:
# English
# 6 299 000+ articles
#
# æ¥æ¬èª
# 1 268 000+ è¨äº
#
# EspaÃ±ol
# 1 684 000+ artÃ­culos
#
# Deutsch
# 2 576 000+ Artikel
#
# Ð ÑÑÑÐºÐ¸Ð¹
# 1 724 000+ ÑÑÐ°ÑÐµÐ¹
#
# FranÃ§ais
# 2 329 000+ articles
#
# Italiano
# 1 693 000+ voci
#
# ä¸­æ
# 1 197 000+ æ¢ç®
#
# PortuguÃªs
# 1 066 000+ artigos
#
# Polski
# 1 473 000+ haseÅ

# %%
req=requests.get("https://www.wikipedia.org/")

# %%
soup=BeautifulSoup(req.text,"html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia</title>
# <meta content="Wikipedia is a free online encyclopedia, created and edited by volunteers around the world and hosted by the Wikimedia Foundation." name="description"/>
# <script>
# document.documentElement.className = document.documentElement.className.replace( /(^|\s)no-js(\s|$)/, "$1js-enabled$2" );
# </script>
# <meta content="initial-scale=1,user-scalable=yes" name="viewport"/>
# <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
# <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>
# <link href="//creativecommons.org/licenses/by-sa/3.0/" rel="license"/>
# <style>
# ...

# %%
a=soup.find_all("div",{"class":"other-project-text"})
for i in a:
    print(i.text)
# Out:
# Commons
# Freely usable photos & more
#
#
# Wikivoyage
# Free travel guide
#
#
# Wiktionary
# Free dictionary
#
#
# Wikibooks
# Free textbooks
#
#
# Wikinews
# Free news source
#
#
# Wikidata
# Free knowledge base
#
#
# Wikiversity
# Free course materials
#
#
# Wikiquote
# Free quote compendium
#
#
# MediaWiki
# Free & open wiki application
#
#
# Wikisource
# Free library
#
#
# Wikispecies
# Free species directory
#
#
# Meta-Wiki
# Community coordination & documentation

# %%
a=requests.get("https://en.wikipedia.org/wiki/Main_Page")

# %%
a
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(a.text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
s=soup.find("ul",{"id":"mp-portals"})

# %%
print(s.text,sep="\n")
# Out:
# The arts
# Biography
# Geography
# History
# Mathematics
# Science
# Society
# Technology
# All portals

# %%
b=requests.get("https://www.wikipedia.org")

# %%
b
# Out:
# <Response [200]>

# %%
soup1=BeautifulSoup(b.text,"html.parser")

# %%
soup1
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia</title>
# <meta content="Wikipedia is a free online encyclopedia, created and edited by volunteers around the world and hosted by the Wikimedia Foundation." name="description"/>
# <script>
# document.documentElement.className = document.documentElement.className.replace( /(^|\s)no-js(\s|$)/, "$1js-enabled$2" );
# </script>
# <meta content="initial-scale=1,user-scalable=yes" name="viewport"/>
# <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
# <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>
# <link href="//creativecommons.org/licenses/by-sa/3.0/" rel="license"/>
# <style>
# ...

# %%
a=soup1.find_all('a',{"class":'link-box'})
a
# Out:
# [<a class="link-box" data-slogan="The Free Encyclopedia" href="//en.wikipedia.org/" id="js-link-box-en" title="English â Wikipedia â The Free Encyclopedia">
#  <strong>English</strong>
#  <small><bdi dir="ltr">6 299 000+</bdi> <span>articles</span></small>
#  </a>,
#  <a class="link-box" data-slogan="ããªã¼ç¾ç§äºå
#  ¸" href="//ja.wikipedia.org/" id="js-link-box-ja" title="Nihongo â ã¦ã£ã­ããã£ã¢ â ããªã¼ç¾ç§äºå
#  ¸">
#  <strong>æ¥æ¬èª</strong>
#  <small><bdi dir="ltr">1 268 000+</bdi> <span>è¨äº</span></small>
#  </a>,
#  <a class="link-box" data-slogan="La enciclopedia libre" href="//es.wikipedia.org/" id="js-link-box-es" title="EspaÃ±ol â Wikipedia â La enciclopedia libre">
#  <strong>EspaÃ±ol</strong>
#  <small><bdi dir="ltr">1 684 000+</bdi> <span>artÃ­culos</span></small>
#  </a>,
# ...

# %%
for i in a:
    print(i.find("strong").text)
    print(i.find("small").text)
    print()
# Out:
# English
# 6 299 000+ articles
#
# æ¥æ¬èª
# 1 268 000+ è¨äº
#
# EspaÃ±ol
# 1 684 000+ artÃ­culos
#
# Deutsch
# 2 576 000+ Artikel
#
# Ð ÑÑÑÐºÐ¸Ð¹
# 1 724 000+ ÑÑÐ°ÑÐµÐ¹
#
# FranÃ§ais
# 2 329 000+ articles
#
# Italiano
# 1 693 000+ voci
#
# ä¸­æ
# 1 197 000+ æ¢ç®
#
# PortuguÃªs
# 1 066 000+ artigos
#
# Polski
# 1 473 000+ haseÅ

# %%
req=requests.get("https://en.wikipedia.org/wiki/Main_Page")

# %%
req
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(req.text,"html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
a=soup.find("ul",{"id":"mp-portals"})
print(a.text,end="\n")
# Out:
# The arts
# Biography
# Geography
# History
# Mathematics
# Science
# Society
# Technology
# All portals
